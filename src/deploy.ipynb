# %%
from URControl import URControl

ur5e_ip = "172.17.0.2"
ur5 = URControl(ur5e_ip)
ur5.connect()
# Out:
# 2026-06-23 02:11:24 - INFO - Connected to robot: 172.17.0.2 on attempt 1

# %%
# %store -r joint_configs

# %%
from tqdm import tqdm

for q in tqdm(joint_configs):
    ur5.move_j(q)
# Out:
# 100%|██████████| 1025/1025 [08:20<00:00,  2.05it/s]
